# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Exploratory-Data-Analysis-and-Metric" data-toc-modified-id="Exploratory-Data-Analysis-and-Metric-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exploratory Data Analysis and Metric</a></span></li><li><span><a href="#Model" data-toc-modified-id="Model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Model</a></span></li><li><span><a href="#Submit" data-toc-modified-id="Submit-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Submit</a></span></li><li><span><a href="#Homework" data-toc-modified-id="Homework-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Homework</a></span></li></ul></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from sklearn.preprocessing  import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import balanced_accuracy_score
import re, string

# %%
SEED = 42

# %%
DATA_PATH = './data/language-detection'

# %%
pd.set_option('display.max_rows', 400)

# %% [markdown]
# **[Kaggle InClass: Language Detection](https://www.kaggle.com/t/bb11ace54b1a465e91b8c3f46a840ce0)**

# %% [markdown]
# # Exploratory Data Analysis and Metric

# %%
train_df = pd.read_csv(f'{DATA_PATH}/train/train.csv')
test_df = pd.read_csv(f'{DATA_PATH}/test/test.csv')

# %%
train_df.shape, test_df.shape
# Out:
# ((3159633, 2), (2784634, 2))

# %%
drop1 = train_df.loc[(train_df['language'] == 'vi') & (train_df['sentence'].str.find('笑') != -1)]

# %%
train_df = train_df.drop(drop1.index)

# %%
train_df.shape
# Out:
# (3134633, 2)

# %%
drop2 = train_df.loc[(train_df['language'] == 'ru') & (train_df['sentence'].str.find('і') != -1)]

# %%
drop2.shape
# Out:
# (75000, 2)

# %%
train_df = train_df.drop(drop2.index)

# %%
drop3 = train_df.loc[(train_df['language'] == 'en') & (train_df['sentence'].str.match('[а-яА-ЯёЁ]+'))]

# %%
train_df = train_df.drop(drop3.index)

# %%
drop4 = train_df.loc[(train_df['language'] == 'fr') & (train_df['sentence'].str.match('[а-яА-ЯёЁ]+'))]

# %%
train_df = train_df.drop(drop4.index)

# %%
drop5 = train_df.loc[(train_df['language'] == 'th') & (train_df['sentence'].str.match('[а-яА-ЯёЁ]+'))]

# %%
train_df = train_df.drop(drop5.index)

# %%
drop6 = train_df.loc[(train_df['language'] == 'th') & (train_df['sentence'].str.find('笑') != -1)]

# %%
train_df = train_df.drop(drop6.index)

# %%
drop7 = train_df.loc[(train_df['language'] == 'et') & (train_df['sentence'].str.match('[а-яА-ЯёЁ]+'))]

# %%
train_df = train_df.drop(drop7.index)

# %%
drop8 = train_df.loc[(train_df['language'] == 'ku') & (train_df['sentence'].str.match('[а-яА-ЯёЁ]+'))]

# %%
train_df.shape
# Out:
# (2884633, 2)

# %%
train_df.drop(drop8.index)
# Out:
#                                                   sentence language
# 0        Pensez à la communication , le discours , les ...       fr
# 1        Můžete si ji pronajmout , vzít na splátky , ko...       cs
# 2        Každý starosta pochopil , že když mají tyto fo...       cs
# 3        Det är ytterligare bevis , men ändå — Jag krit...       sv
# 4                                      كان الأمر لا يصدق .       ar
# ...                                                    ...      ...
# 3159628                    そんな所で捕まっている片手は 70億の人々と繫がる命綱なのです       ja
# 3159629  Първоначално се опитах да направя думите &quot...       bg
# 3159630  Ho appreso che ha a che fare con l&apos; atten...       it
# 3159631  E os edifícios não se limitam a apenas evocar ...    pt-br
# 3159632  La « Danse d ’ entrée du mariage JK » est deve...    fr-ca
#
# [2834633 rows x 2 columns]

# %%
train_df.shape
# Out:
# (2884633, 2)

# %%
drop9 = train_df.loc[(train_df['language'] == 'ku') & (train_df['sentence'].str.match('[а-яА-ЯёЁ]+'))]

# %%
drop10 = train_df.loc[(train_df['language'] == 'ta') & (train_df['sentence'].str.find('the and of it that you to apos we this') != -1)]

# %%
train_df = train_df.drop(drop10.index)

# %%
lang_count = (
    train_df.language.value_counts()
    .to_frame()
    .reset_index()
)

lang_count.head()
# Out:
#   index  language
# 0    en    132655
# 1    ar    110032
# 2    he    108663
# 3    ru    106970
# 4    ko    105638

# %%
train_df.loc[train_df['sentence'].str.find('笑') != -1]['language'].unique()
# Out:
# array(['ja', 'zh-cn', 'zh-tw', 'zh'], dtype=object)

# %%
train_df.loc[train_df['sentence'].str.match('[а-яА-ЯёЁ]+')]['language'].unique()
# Out:
# array(['ru', 'bg', 'ku', 'uk', 'sr', 'mn', 'mk', 'be', 'kk', 'es'],
#       dtype=object)

# %%
sr = train_df.loc[(train_df['language'] == 'sr')]

# %%
nodrop = train_df.loc[(train_df['language'] == 'sr') & train_df['sentence'].str.match('[а-яА-ЯЂђЈјКкЉљЊњЋћЏџ ().,]+')]

# %%
drop11 = sr.drop(nodrop.index)

# %%
drop11.head(300)
# Out:
#                                                 sentence language
# 56     Ali neke zemlje imaju čvršći stav o ovome od o...       sr
# 92     Na kraju se ispostavilo da ima puno pojava koj...       sr
# 127    Na vrhu ovog ogromnog aparata , bio je jedan č...       sr
# 136    Ali geni u ovim pećinskim ribama nam takođe mo...       sr
# 139            Mnogi ljudi u Meksiku su danas uplašeni .       sr
# 165               Težimo našim individualnim ciljevima .       sr
# 190    Moramo da globalno učinimo mnogo više kako bis...       sr
# 228    Mislim da je to što je taj rad toliko težak , ...       sr
# 273    Mikrofinansije su vrlo moćna alatka na putu ka...       sr
# 283    Na kraju , amigdale kod psihopata su u proseku...       sr
# 382                           Da bi bila jedna od njih ?       sr
# 396    Dakle , slažemo ove listove jedan na drugi , k...       sr
# 499    Isto tako , ako zaista nekome želite dobro , v...       sr
# 514    Ili siromašni koji ismevaju bogate , isto kao ...       sr
# 544       Ili možda Veliki prasak nije početak svemira .       sr
# 580    Ali u kulturi opsednutoj imidžom , učimo našu ...       sr
# 600    To se potom može staviti u prostor , jer je ve...       sr
# 606    Jedan od devet ljudi koji je osuđen na smrt , ...       sr
# 704                                    Pa , šta radimo ?       sr
# 713    To je E sa promenjenom perspektivom zato što i...       sr
# 808    Oživeo sam karijeru , još više nego što je bil...       sr
# 832                                   KA : To je dobro .       sr
# 894    Preuzimam kontrolu fizičkom snagom , i zadržav...       sr
# 1162   Možda nas nema tako puno , ali ako se promoviš...       sr
# 1279   Naposletku , ovde smo da bismo zajedno sanjali...       sr
# 1293   Pogledajte slavu i izdašnost okruga Bronks . N...       sr
# 1371   Našli smo ih u Japanu , Švedskoj , Nemačkoj , ...       sr
# 1413   Vidite vlakna , vidite svetlo nevidljive mater...       sr
# 1432                            Hvala puno . Doviđenja .       sr
# 1506   Ali moj tim i ja smo uvereni da možemo ovo da ...       sr
# 1512     Međutim , njihov rad je na neki način odbačen .       sr
# 1533   Radi se o ispravnoj obuci budućih zdravstvenih...       sr
# 1540   Nažalost , empirijski podaci , dobre , pouzdan...       sr
# 1546                  Mislim da ću slediti bakin savet .       sr
# 1550   Nekako kolektivno pretpostavljamo da su izbegl...       sr
# 1578                                    Ići će sa mnom .       sr
# 1588   priču o Budrusu , bila sam iznenađena da međun...       sr
# 1589                              Ponavljali smo scene .       sr
# 1593   Pa sam nekako tih prvih noći u Njujorku želela...       sr
# 1625   A samo 15 minuta dalje od izbegličkog kampa Za...       sr
# 1667                              Manje nije uvek više .       sr
# 1848                Prilično je jasno da to nije dobro .       sr
# 1898   Postoji mnogo , mnogo načina snimanja CD-a ili...       sr
# 1926   U ovim zemljama broj stručnjaka bio je zaista ...       sr
# 1984   Teško je postići tu ravnotežu , reći detetu da...       sr
# 1993   I što je važnije , šta ćemo da uradimo u vezi ...       sr
# 2072     Zatim tu su novi izazovi koje nismo očekivali .       sr
# 2195   Jednim udahom , zaplivajte sa mnom duboko u je...       sr
# 2227   Ona je bila u džemperu jer je već bila mrkla n...       sr
# 2299   Nekad je bilo uobičajeno za ljude poput vas da...       sr
# 2332   I ako je ugao dobar , možete čak i videti holo...       sr
# 2340   Ali na svetlo obično ne izađe to kako se ove k...       sr
# 2380   Stavite vašu knjigu naspram nje i možete da či...       sr
# 2382   Dakle , mene zanima tekstura , ali me više int...       sr
# 2409   Koliko god vi mislili , kao ja , da niste takv...       sr
# 2416                  Dakle , osmotrio sam je pažljivo .       sr
# 2437   Išao sam do lokalne prodavnice i do farmera ko...       sr
# 2463   A onda sam rekao : &quot; &quot; Zbogom . &quo...       sr
# 2474   Napuštanje fosilnih goriva znači remećenje naš...       sr
# 2486      I ponekad moramo verovati čak i kompjuterima .       sr
# 2488                       Sida je bila smrtna presuda .       sr
# 2490   Međutim , kad ih pogledate , njih ne podstiče ...       sr
# 2509                                    Dakle , evo ga .       sr
# 2525   Ne verujem da su radili sve te stvari , a da n...       sr
# 2559   &quot; &quot; Пошто је први интернет претражив...       sr
# 2631            Počećemo od fioka i veličine frižidera .       sr
# 2657     Arapski jezik ne zadovoljava današnje potrebe .       sr
# 2659   U digitalnnom životu morate da se predstavite ...       sr
# 2663                       Imali smo žurku u pidžamama .       sr
# 2718                 I ozbiljno , mogu da nosim štikle .       sr
# 2737   U ovom slučaju , radi se o ljudskom sistemu za...       sr
# 2829   Dno je potpuno promenjeno , prešlo je od tvrdo...       sr
# 2847   Oni su veoma graciozni.Čarls Darvin je rekao d...       sr
# 2850   Ni u jednom momentu neću reći da je tehnološka...       sr
# 2923   Ako bi formu pratila fikcija , mogli bismo da ...       sr
# 2953   Po završetku ove sesije , izlazite sa kopijom ...       sr
# 2972     Imaš tako moćnu viziju . Ti si žena s vizijom .       sr
# 3036   Kada promenite svoje mišljenje o stresu , može...       sr
# 3118   Ne morate da podižete ruke budući da svi mi im...       sr
# 3125                               EM : Okej , Atlanta .       sr
# 3347                    U podršci , u tvojim poslovima .       sr
# 3366   Što je još sjajnije , ne morate biti na istoj ...       sr
# 3474   Tu se mnogo više dešava , ali neću puno govori...       sr
# 3517                 Znam da neki od vas rade na ovome .       sr
# 3582   I moram vam reći da ono što sam video , u svet...       sr
# 3583   Ili ako bi vaš gost na večeri nakon obroka izv...       sr
# 3596   Odjednom vidimo gusenicu monarha kako gricka b...       sr
# 3613   Na drugom kraju planete , Antarktiku , najvećo...       sr
# 3652   Gledala je kako se zatvaraju čeličane a belci ...       sr
# 3846   To znači da , kada ispitujemo ljude i uočimo o...       sr
# 3872   Da li to radite da zaštitite svoj narod od ter...       sr
# 3881                                    Sve se promenilo       sr
# 3947   Pa čak i kad to radi , čini se da ih baš i ne ...       sr
# 3977   Ono što pokušavam da shvatim je sledeće : vaše...       sr
# 4003   U UK , broj maturanata koji su pohađali dodatn...       sr
# 4022          Naše najbolje oružje je sunčeva svetlost .       sr
# 4200   U jednom trenutku je samo rekao : &quot; &quot...       sr
# 4233                          Pa , da , apsolutno može .       sr
# 4352   Ali istina je da ako su bogati i moćni pojedin...       sr
# 4361   Napadali smo stoletne običaje u tim zajednicama .       sr
# 4377                           Imamo jako malo slobode .       sr
# 4386   Četvoromosečno mladunče albatrosa je uginulo s...       sr
# 4390   Dakle , imam ovde mali papir , najviše zbog to...       sr
# 4397                     Mislim , trebalo je videti to .       sr
# 4436   Možemo izabrati da imamo različite rejting age...       sr
# 4446   Njegovo ime je Džim , Džim Smit , i izgledao j...       sr
# 4529                 No , svi smo mi bili jednom ružni .       sr
# 4556   Bio sam tamo kao nezavisni izveštač , i sve št...       sr
# 4650   Predoziranje je u velikoj meri opalo , kao i p...       sr
# 4676   Tokom mojih putovanja i rada u Kongu i Avganis...       sr
# 4764                                 Nije bilo toaleta .       sr
# 4768   To je super , ali mi smo ga snimili sa 44 godi...       sr
# 4815                          Granice svega će nestati .       sr
# 4839   Pa , budućnost , naravno , ima jedan ogroman i...       sr
# 4878   Prostor koji nas ne prati uvek poput psa koji ...       sr
# 4925                             U redu , upoznajte se .       sr
# 4930   Ne možemo se zavaravati da su previše kompliko...       sr
# 5140                  Niko od tada nije došao ni blizu .       sr
# 5149   Ali 106 prosto nije dovoljno da je učini moćno...       sr
# 5183   KA : Ed , mislim da si čitao predlog o kom je ...       sr
# 5198   Sada usmeravamo naše superoružje ka njegovom p...       sr
# 5242           Kako smo se vodili time , zapinjali smo .       sr
# 5309   Biolozi koji proučavaju svilu pokušavaju da po...       sr
# 5325   Razmišljaju o njima kao o nečem što nervira , ...       sr
# 5423                              Nema pravog odgovora .       sr
# 5424         Ali pitanje je , da li je to dobro za nas ?       sr
# 5492   Ako dodamo matricu , ako dodamo jezik struktur...       sr
# 5529   A zatim , to je daleko više od pukog ubrizgava...       sr
# 5642   A šta sam uradio posle toga ? Obično , kada ne...       sr
# 5643   Muzika je na neki način drugačija , ali u stru...       sr
# 5732         Sada imamo polet . Ovo je ključni momenat .       sr
# 5825                         Ja radim u SETI institutu .       sr
# 5871      Ali svila je svestrana i ide dalje od optike .       sr
# 5920   Kako da znamo , kada gledamo u nešto , da li j...       sr
# 5977   Pre svega , samo iskustvo je bizarno , veoma b...       sr
# 6027                       Želiš pornografske časopise ?       sr
# 6169                        I Kinezi su joj poverovali .       sr
# 6204   Ovo je puna bočica &quot; &quot; Kalms Fortea ...       sr
# 6327                    a ključ za kulturu je religija .       sr
# 6359                         Osećaj je nekako uzdižući .       sr
# 6485                            Dozvolite mi digresiju .       sr
# 6492   Od skora je možete naći samo u oblastima oko e...       sr
# 6614   Sećam se kada sam sa 5 godina na Filipinima ho...       sr
# 6632   Naravno , visina ide često pod ruku sa tempom ...       sr
# 6747               Stalno stvaramo napetost i probleme .       sr
# 6807                                              A vi ?       sr
# 6938   Da li je fer proceniti režim lečenja koji nije...       sr
# 7177   Zapravo , što bolje radim svoj posao , to me l...       sr
# 7185                              Recimo građenje kuća .       sr
# 7257   Ovo biste nosili sa sobom , i ako bi sve krenu...       sr
# 7359          Počeli smo da otkrivamo ugravirane spise .       sr
# 7501   Umesto toga , koristio je prefinjeni sistem ps...       sr
# 7520   K. A. : Hvala vam , Govorili ste odlično . Hva...       sr
# 7594                    Ovo je artemija , vrsta škampi .       sr
# 7719   Rekli smo : &quot; &quot; Plemena u kojima se ...       sr
# 7746   Širio se kao vatra neki su umirali i nekoliko ...       sr
# 7809   Dakle , naše istraživanje - i mislim istraživa...       sr
# 7873   Ali ti sistemi u sebi sadrže na milione drugih...       sr
# 7878   I svojevrsno &quot; &quot; ponovno rođenje &qu...       sr
# 7897         Većina ljudi se odluči za bezbednu opciju .       sr
# 7910            Drugo , poboljšati zdravlje populacije .       sr
# 7967   U svakoj situaciji , oni bi našli način da gov...       sr
# 8028   Ovo sam naučila na poslu sa tvorcima politike ...       sr
# 8055                               Vratimo se plastici .       sr
# 8094   I sad vidite kako se embrion razdvaja , i 14 j...       sr
# 8110   Ali istovremeno , narod Kine postavlja ovo pit...       sr
# 8139                                   To je tek čudno .       sr
# 8223   I rekla bi kako oni bukvalno vizualizuju lica ...       sr
# 8227                      To je udaljenost od 9 metara .       sr
# 8231      KK : A-ritAm-etika . Publika : A-ritAm-etika .       sr
# 8334   Kompanije su pratile metodu vodopada , u kojoj...       sr
# 8381   Ona predstavlja rizik , jer se žrtvuje krajnja...       sr
# 8402            Adama II čini vaša borba sa slabostima .       sr
# 8413   Pojavila se gljivica koja izaziva rđu , bube k...       sr
# 8505   Žene u selima nisu imale pojma da se borimo za...       sr
# 8539   Ivan se vraća i kaže „ Hoću svoj sendvič sa si...       sr
# 8542   Vazduhoplovna kontrolna lista , kao ova za avi...       sr
# 8556                       S pet hitaca je pogodio Dea .       sr
# 8614   Dakle , to nije teorija svega . Zapravo , ogro...       sr
# 8633   I to su obično osnovni naučnici , na dnu su ob...       sr
# 8664   Kreće na žurku na kampusu gde vidi dečka koji ...       sr
# 8680   ŠOĆ : Da li bi ti voleo da izvršiš samoubilačk...       sr
# 8764     Pokrivali smo više od 50 gradova u isto vreme .       sr
# 8982   Rusija . Čad je hteo da se bori protiv homofob...       sr
# 8988   Zatim bi nam bio potreban način da ih pretvori...       sr
# 9019   Zavisnost je stvarna , pojave su stvarne , sak...       sr
# 9083   Takođe , ljudi poput mene , vode dve bitke na ...       sr
# 9124   Tako se danas ne fokusiramo samo na raspodelu ...       sr
# 9327   Ne biste verovali koliko je lako da ubedite lj...       sr
# 9403                          Hoćete li ići na sigurno ?       sr
# 9434                            Nisu bili nepustolovni !       sr
# 9453      Nije dozvoljeno , ali nije ni protivzakonito .       sr
# 9468   Moja grupa , L.A. Zelene Površine i ja smo se ...       sr
# 9569   Bio je neorganizovan , nestalan , dosta toga n...       sr
# 9582   Ako uzmete kompletno nuklearno naoružanje napr...       sr
# 9644   Sledeći dobro prostudirani zvuci su eholokacij...       sr
# 9708   Možda bih trebao da registrujem još koje za sv...       sr
# 9743   Ovo su tmurna ekonomska vremena , prijatelji s...       sr
# 9782   Japan je bio prvo društvo van zapada koje je o...       sr
# 9824   Ukazala sam na njih : obrazovanje i ekonomske ...       sr
# 9888   Vidite , to je rad . Gledajte , sistem nije bl...       sr
# 9890   To je ono što zovete &quot; &quot; problemom p...       sr
# 9948   Neki kažu da je moguće da se to dešava , ali i...       sr
# 9984   Kao životinje kojima je data moć racionalnog m...       sr
# 10039                        U stvari , već ih ubijaju .       sr
# 10063  I sada treba da se odreknete novca i pošaljete...       sr
# 10087  50-tih godina - ( Aplauz ) 50-tih godina , poč...       sr
# 10150  Možemo koristiti jednačine evolucije da bismo ...       sr
# 10222  Stoga , dok se krećemo napred ka ovoj tehnološ...       sr
# 10310  Uzeli su sva ispitivanja koja su predata u FDA...       sr
# 10324                Činjenica je da ugalj nije prljav .       sr
# 10451  Bila sam na dugom putovanju ovog leta i divno ...       sr
# 10484  Pesma se zove &quot; &quot; Libation &quot; &q...       sr
# 10514                  Gorgonari osciliraju s talasima .       sr
# 10543  Pa smo napravili veliku rotirajuću komoru , a ...       sr
# 10638             Još uvek nemam reč za to , ali imaću .       sr
# 10735  Napravili su ribnjak od oko 10,000 ha - grgeč ...       sr
# 10848  Možemo stvoriti mnogo komplikovanije strukture...       sr
# 10881                         Sve je to daleko , znate .       sr
# 10962  Sve je crno i belo , mi i oni , ispravno i pog...       sr
# 11075         Henri Ford je živeo u drugačijem vremenu .       sr
# 11090                                       Bez obzira .       sr
# 11156  U redu , vidite u čemu je stvar , zar ne ? ( S...       sr
# 11214  Postoje neverovatne mogućnosti koje se mogu do...       sr
# 11241  Ne znam zašto mi stalno pada na pamet da je Dž...       sr
# 11369  Kristofer Pul : Kada sam imao petnaest godina ...       sr
# 11374  I svako od nas naravno zna da se dug federalne...       sr
# 11380  Moj istraživački tim i ja smo rešili da ispita...       sr
# 11411  Hajdete sad . Pogledajte ovog tipa . Znate li ...       sr
# 11469  Crvene su jedna vrsta , plave su druga , a zel...       sr
# 11510  Pa sam odlučila da pokrenem thedailydenouncer....       sr
# 11520                           Radim to već 30 godina .       sr
# 11558  Shvatio sam da me fotografisanje gotovo obuzima .       sr
# 11571  Rasti Šveikart , koji je bio astronaut na Apol...       sr
# 11649                     Jedan od njih pada na zemlju .       sr
# 11754  U suštini , to je sila koja deluje na tkivo kr...       sr
# 11759  Nikad nećete sresti jednog jedinog čoveka na s...       sr
# 11785  Ponovo smo prikupili objektivne mere fizičke s...       sr
# 11797  I iako nemam patent za koji znam , upoznaćete ...       sr
# 11831  Dosta slika koje vam pokazujem su prelepe , al...       sr
# 11834  Čovek sa širom otvorenim očima bi mi ga možda ...       sr
# 11904  Naša reklama je bila svuda u etru , i žene su ...       sr
# 11931     Ali ipak se to polovini pacijenata ne događa .       sr
# 11938  Htela bih i da brodski transport i mi , opšta ...       sr
# 11992  Ali &quot; &quot; Čarobnjak iz Oza &quot; &quo...       sr
# 12002                                 pa uzmete pilule .       sr
# 12028  U tami , neki su izgubili svoj oslonac i pali ...       sr
# 12108  A samo ovo drugo je umetnikova odgovornost . &...       sr
# 12122              Bez vode , bakterije neće preživeti .       sr
# 12123  Ovo je snimak od prošlog leta kad smo ponovo p...       sr
# 12183  Nasuprot tome , tačno je i da Internet ima pro...       sr
# 12223                                       Razumem to .       sr
# 12228  Biće paradoks ukoliko se ovi izolovani Indijan...       sr
# 12261  Postoji i drugi razlog zašto mi se sviđaju ti ...       sr
# 12414  Amartia Sen dobio je Nobelovu nagradu zato što...       sr
# 12571                        Morao sam da naučim jezik .       sr
# 12664  i kada izaberete da vidite stres na ovaj način...       sr
# 12814                   „ Не , Андрес , она се не шали .       sr
# 12838         Ima samo jedan pomerajući deo , propeler .       sr
# 12914   Koji su to neverbalni izrazi moći i dominacije ?       sr
# 13034  Mislim da će se u budućnosti , materijali razv...       sr
# 13085  Pomislili samo da možda pokušavaju da se sklon...       sr
# 13153  Kaže nam da smo mi i sve oko nas zapravo jedan...       sr
# 13172        Reforma tržišta se pokazala uspešnom ovde .       sr
# 13225  Da li će mi dati stručne časopise da škrabam p...       sr
# 13232  Ova vrsta slobode je ciljana i ima precizan ok...       sr
# 13313     Novine postanu zastarele čim izađu iz štampe .       sr
# 13325  Ipak , priča sa Haitija takođe ilustruje neke ...       sr
# 13334  97 одсто копна на Галапагос острвима је заштић...       sr
# 13366  Nepoverenje je oduvek bilo jako bitno za demok...       sr
# 13367  Naša lokalna vlast je već odlučila da svuda na...       sr
# 13559  Prodavanje devojaka je zastupljeno po celoj pl...       sr
# 13612                                        Hvala vam .       sr
# 13836  Kao i letelice sa fiksiranim krilima , efikasn...       sr
# 13862  Ali ako ne dobiju 12 dana , mogu da upadnu u o...       sr
# 13976  Malarija : ima 8 zemalja u Podsaharskoj Africi...       sr
# 14018  To je jedan od razloga zašto je Artur Andersen...       sr
# 14080                         Imaju tri osnovne opcije .       sr
# 14083  Drugi ljudi . Svi su zainteresovani za druge l...       sr
# 14188  K.A : Kakve razgovore si imao ili još uvek ima...       sr
# 14223  Oni se i skupljaju i povlače — a neki od njih ...       sr
# 14258  Leblon ima ILJR , indeks ljudskog razvoja , 0,...       sr
# 14331   Švajcarska ambasada u Berlinu je nešto posebno .       sr
# 14377                       Zaboravio je da popije lek .       sr
# 14535  Stoga se zapitajte sledeće : šta je zaista omo...       sr
# 14568  Gledamo ljude u Sjedinjenim Državama koje je I...       sr
# 14767  Znači zamena DNK bakterije sa DNK virusa pretv...       sr
# 14814  Zašto misliš da je tako ? &quot; &quot; I razm...       sr
# 14872  Početkom 80-ih , stavljena je zabrana na komer...       sr
# 14907  Mogli bi reći , &quot; &quot; Imam malo nektar...       sr
# 14940  Kada sam počela tamo da radim , otprilike 1 % ...       sr
# 14955                Njihov život ima usmerenu putanju .       sr
# 15030  Potom , na kraju staklenika veliki deo te vlag...       sr
# 15074  Ono što je zaista pokrenulo modenu neuronauku ...       sr
# 15182                     Pa , imam dobre i loše vesti .       sr
# 15371         To su vam uobičajeni digitalni mrzitelji .       sr
# 15404  Sada tu ima 22 urbana pešačka bloka sa javnim ...       sr
# 15423  Mislim da bi ovo apsolutno trebalo da bude pri...       sr
# 15461  To će povećati privatnost i prava koja ljudi u...       sr
# 15498  Onda smo pročitali vašu knjigu i promenile svo...       sr

# %%
train_df = train_df.drop(drop11.index)

# %%
drop12 = train_df.loc[train_df['sentence'].str.len() <= 1]

# %%
train_df.loc[train_df['sentence'].str.find('♫') != -1].head(400)
# Out:
#                                                  sentence language
# 1075    ♫ 有著突出的肚皮 ♫ ♫ 眼裡有蒼蠅 ， 頭大身小的比例 ♫ ♫ 只是另一個餓壞的孩子 ♫...    zh-tw
# 1700    ♫ Her istediğini yapamazsın ♫ ♫ CD satışları h...       tr
# 3134    ♫ Não precisamos de mais problemas ♫ Tire esse...    pt-br
# 3956    ♫ The explorers slaughtered the braves . ♫ Swe...       en
# 4207    ♫ ووووو - هوووووو ! ♫ ♫ دا , دا , دا , دا , دا...       ar
# 5385    ( מוסיקה ) ♫ קדימה , ברך את עצמך ♫ ♫ הושט לעצמ...       he
# 5970    ♫ Sólo rompo otro cuello de botella y toco est...       es
# 8437    ♫ בעניין החדשות שהיו לי היום ? ♫ ♫ איני יודע ♫...       he
# 9147    ♫ Sonsuza dek bekleyemem ♫ ♫ soğuk havaya daya...       tr
# 9600    สมมติว ่ า ถ ้ าฉันเล ่ นท ่ อนสั ้ นๆของบทเพล...       th
# 10533   ♫ ndoshta feshkellima e nje kenge ♫ ♫ apo zuka...       sq
# 11162   Dit lied is een van Thomas &apos; favorieten ,...       nl
# 11375   ♫ Hey , hey , ¡ Susie de los ojos negros ! Hey...       es
# 11874   ♫ 想像你身處在沒有人的世界 ♫ ♫ 四周無人 ♫ ♫ 曾經可以聆聽的聲音 可以仰望的面孔 ...    zh-tw
# 13436   ♫ mas todo o plástico já feito , ainda está aq...    pt-br
# 14397   ♫ Kendini başka kimsenin olmadığı bir dünyada ...       tr
# 18248   ♫ Du bist es nicht wert ... ♫ ♫ Mit deinen ber...       de
# 18974   ♫ Platon w jaskini z tymi bardzo młodymi chłop...       pl
# 23188   ♫ que o rapaz que pegou a sua cerveja ♫ ♫ era ...    pt-br
# 23789   ♫ 就是这样的简单 ， ( 狗的喘息声 ) 哈 ， 哈 ， 哈 ， 哈 。 ♫ ♫ 就是这样...    zh-cn
# 446856  ♫ מטיילת בסנטרל פארק ♫ ♫ כולם בחוץ היום ♫ ♫ כל...       he
# 447218    ♫ المستكشفون ذبحوا الشجعان . ♫ سويني : بفظاعة .       ar
# 447815  ♫ Nu hebben we iets voor &apos; t diner ♫ ♫ Je...       nl
# 448802  ♫ Buvau turtinga , bet ligota , niekas negyven...       lt

# %%
test_df.loc[test_df['sentence'].str.len() <= 1]
# Out:
#            index sentence
# 54723      54723        -
# 86082      86082        日
# 158646    158646        .
# 163848    163848        血
# 169470    169470        3
# 169545    169545        .
# 215852    215852        -
# 227457    227457        對
# 243420    243420        `
# 260206    260206        哇
# 274046    274046        ８
# 345348    345348        对
# 346930    346930        -
# 361327    361327        .
# 409154    409154        對
# 473029    473029        -
# 589002    589002        ７
# 617594    617594        錯
# 711616    711616        .
# 750892    750892        -
# 843689    843689        瞧
# 860152    860152        -
# 886561    886561        ね
# 946874    946874        -
# 958848    958848        -
# 965817    965817        .
# 989511    989511        —
# 994382    994382        對
# 1003647  1003647        네
# 1124522  1124522        —
# 1146959  1146959        好
# 1203112  1203112        -
# 1276194  1276194        -
# 1285738  1285738        恩
# 1310055  1310055        -
# 1316303  1316303        -
# 1321917  1321917        不
# 1329486  1329486        好
# 1329698  1329698        -
# 1362729  1362729        -
# 1363695  1363695        .
# 1384792  1384792        折
# 1431310  1431310        —
# 1447712  1447712        -
# 1495181  1495181        對
# 1582999  1582999        -
# 1600202  1600202        -
# 1655992  1655992        .
# 1672904  1672904        네
# 1673529  1673529        .
# 1737270  1737270        피
# 1746349  1746349        .
# 1845748  1845748        -
# 1889405  1889405        嗯
# 1893923  1893923        不
# 1898124  1898124        -
# 1942280  1942280        人
# 1960791  1960791        —
# 2059318  2059318        噢
# 2126291  2126291        Ồ
# 2171399  2171399        `
# 2215651  2215651        네
# 2280634  2280634        .
# 2333162  2333162        .
# 2398937  2398937        錯
# 2404626  2404626        -
# 2453922  2453922        .
# 2466102  2466102        走
# 2505927  2505927        .
# 2511132  2511132        .
# 2514451  2514451        好
# 2514920  2514920        _
# 2532587  2532587        -
# 2567489  2567489        雲
# 2676700  2676700        -
# 2694006  2694006        —
# 2735638  2735638        .
# 2752549  2752549        次

# %%
drop11.shape
# Out:
# (57215, 2)

# %%
lang_count = (
    train_df.language.value_counts()
    .to_frame()
    .reset_index()
)

lang_count.head()
# Out:
#   index  language
# 0    en    132655
# 1    ar    110032
# 2    he    108663
# 3    ru    106970
# 4    ko    105638

# %%
fig, ax = plt.subplots(figsize=(8,25))

ax.barh(lang_count['index'], lang_count['language'])
ax.invert_yaxis();

# %%
lang_count[lang_count['index'].apply(lambda x: x in {"en", "kk"})]
# Out:
#    index  language
# 0     en    132655
# 58    kk      2046

# %% [markdown]
# Датасет сильно не сбалансирован по классам, а требуется хорошее качество для всех языков, поэтому метрика в данном соревновании — взвешенная доля правильных ответов:
#
# $$
# \text{WeightedAccuracy}\left(y, \hat{y}, w\right) = \frac{\displaystyle{\sum_{i=1}^{n}} w_i \cdot \left(y_i == \hat{y}_i\right)}{\displaystyle\sum_{i=1}^{n} w_i }
# $$
#
# Веса выбирались обратно пропорционально количеству примеров соответствующего языка:
# $$
# w\left(\text{"en"}\right) \sim \frac{1}{157655}
# $$
# $$ \dots $$
# $$
# w\left(\text{"kk"}\right) \sim \frac{1}{2046}
# $$
#
# Поэтому для валидации можно использовать [sklearn.metrics.balanced_accuracy_score](https://scikit-learn.org/stable/modules/model_evaluation.html#balanced-accuracy-score)

# %% [markdown]
# # Model

# %%
x = train_df.values[:, 0]
label_encoder = LabelEncoder().fit(train_df.values[:, 1])
y = label_encoder.transform(train_df.values[:, 1])

# %%
# x_test = train_df.values[200000:250000, 0]
# y_test = label_encoder.transform(train_df.values[200000:250000, 1])

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
regex = re.compile('[%s]' % re.escape('♫()'))
def preprocessor(s):
    return regex.sub('', s)

# %%
word2vec = gensim.models.Word2Vec(
    size=100, sg=0, window=5, min_count=5, negative=20
)
word2vec.build_vocab(sentence_dataset)

# %%
pipe = Pipeline([
    ('vectorizer', TfidfVectorizer(lowercase=True, ngram_range=(4, 4), analyzer='char')),
    ('model', SGDClassifier(random_state=SEED, loss='modified_huber', class_weight='balanced'))
])

# %%
pipe.fit(x, y)
# Out:
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(analyzer='char', ngram_range=(4, 4))),
#                 ('model',
#                  SGDClassifier(class_weight='balanced', loss='modified_huber',
#                                random_state=42))])

# %%
predictions = pipe.predict(x)

# %%
predictions_train = pipe.predict(x)

# %%
balanced_accuracy_score(y, predictions_train)

# %% [markdown]
# 0.9688728929365763

# %%
predictions = pipe.predict(x_test)

# %%
balanced_accuracy_score(y_test, predictions)

# %% [markdown]
# 0.5018507409493286 (это вроде если только русский от украинского и беларусского почистить)
# 0.4445904874245853 (почему так???) (это если почистить все)
# 0.4782809098198808 (вот отчистка ток русского)
# 0.477780221367612 (drop1 и drop2)
# 0.4737252251368976 (drop5 drop6)
# .9341363897080626
# 0.9409408631028531
# 0.9453915679112486
#
# 0.8788040761302176
# 0.8801640538177106
# 0.8900323070425553 hinge
# 0.8941617556960667 modufied huber
#
# 0.9040040216092206

# %% [markdown]
# # Submit

# %%
submit_predictions = pipe.predict(test_df.sentence.values)

# %%
test_df['language'] = label_encoder.classes_[submit_predictions]

test_df.head()
# Out:
#    index                                           sentence language
# 0      0                                         תודה לכם .       he
# 1      1  Precisamos de compaixão para começar , e auto-...    pt-br
# 2      2                            這個增長相當大 ， 並且它將引發經濟的增長 。    zh-tw
# 3      3                 시애틀에서 자란 제가 처음 가난을 보게 되던 때를 기억해요 .       ko
# 4      4                                    これをロボットに組み込みました       ja

# %%
(
    test_df[['index', 'language']]
    .to_csv(f'{DATA_PATH}/sample_submission.csv', index=False)
)

# %%
# !head $DATA_PATH/sample_submission.csv
# Out:
# index,language
# 0,he
# 1,pt-br
# 2,zh-tw
# 3,ko
# 4,ja
# 5,zh-tw
# 6,hu
# 7,nl
# 8,ru

# %% [markdown]
# # Homework
#
# - выбить хороший score на private leaderboard'е (8 баллов)
# - совет: поищите ошибки в train-части датасета
